# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('ulabox_orders.csv', header=0)
df.shape
# Out:
# (30000, 14)

# %%
df.head(n=10)
# Out:
#    customer  order  total_items  discount%  weekday  hour  Food%  Fresh%  \
# 0         0      0           45      23.03        4    13   9.46   87.06
# 1         0      1           38       1.22        5    13  15.87   75.80
# 2         0      2           51      18.08        4    13  16.88   56.75
# 3         1      3           57      16.51        1    12  28.81   35.99
# 4         1      4           53      18.31        2    11  24.13   60.38
# 5         1      5            8      23.89        4    13   0.00  100.00
# 6         1      6           35      17.26        1    10  13.01   51.84
# 7         1      7           12       6.61        4     8  17.21   67.93
# 8         1      8           35      22.29        1    12  15.50   61.65
# 9         1      9           44      20.39        2    12  15.29   44.11
#
#    Drinks%  Home%  Beauty%  Health%  Baby%  Pets%
# 0     3.48   0.00     0.00     0.00    0.0    0.0
# 1     6.22   2.12     0.00     0.00    0.0    0.0
# ...

# %%
df.describe()
# Out:
#            customer         order   total_items     discount%       weekday  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    5012.483367  14999.500000     31.739933      8.455495      3.642367
# std     2888.646245   8660.398374     20.576579     14.199350      2.122031
# min        0.000000      0.000000      1.000000    -65.150000      1.000000
# 25%     2541.750000   7499.750000     18.000000      1.177500      2.000000
# 50%     5043.000000  14999.500000     29.000000      4.160000      3.000000
# 75%     7483.000000  22499.250000     41.000000      9.990000      5.000000
# max    10238.000000  29999.000000    298.000000    100.000000      7.000000
#
#                hour         Food%        Fresh%       Drinks%         Home%  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      15.034667     23.560406     20.227279     23.349235     13.539575
# ...

# %%
# Histograms
df["total_items"].hist()

# %%
# Unique values
df["customer"].unique()
# Out:
# array([    0,     1,     2, ..., 10236, 10237, 10238], dtype=int64)

# %%
# frequency count of column A 
df.groupby(['customer']).count()
# Out:
#           order  total_items  discount%  weekday  hour  Food%  Fresh%  \
# customer
# 0             3            3          3        3     3      3       3
# 1            20           20         20       20    20     20      20
# 2             1            1          1        1     1      1       1
# 3            23           23         23       23    23     23      23
# 4            29           29         29       29    29     29      29
# ...         ...          ...        ...      ...   ...    ...     ...
# 10234         1            1          1        1     1      1       1
# 10235         1            1          1        1     1      1       1
# 10236         1            1          1        1     1      1       1
# 10237         2            2          2        2     2      2       2
# 10238         1            1          1        1     1      1       1
#
#           Drinks%  Home%  Beauty%  Health%  Baby%  Pets%
# customer
# ...

# %%
ula_pivot = pd.pivot_table(df, values='order', index='customer', aggfunc='count')
print(ula_pivot)
# Out:
#           order
# customer
# 0             3
# 1            20
# 2             1
# 3            23
# 4            29
# ...         ...
# 10234         1
# 10235         1
# 10236         1
# 10237         2
# 10238         1
#
# [10239 rows x 1 columns]

# %%
plt.hist(df['order'], bins=50)
plt.show()
msg = "There are %d unique customers in the dataset of %d orders" % (len(df), len(df))
print(msg)
ula_pivot.order.value_counts().head()
# Out:
# There are 30000 unique customers in the dataset of 30000 orders
# 1    4479
# 2    1944
# 3    1180
# 4     862
# 5     492
# Name: order, dtype: int64

# %%
# Filtering
df[df["weekday"]==7].head() # only the Sunday orders appear
# Out:
#     customer  order  total_items  discount%  weekday  hour  Food%  Fresh%  \
# 25         3     25           67       4.19        7    21  12.47   68.13
# 44         3     44           23       7.23        7    19  17.31   72.43
# 55         4     55           23       5.81        7    21   0.00   53.76
# 58         4     58           15       2.37        7    20   0.00   66.51
# 59         4     59           31       5.46        7    21   2.82   63.50
#
#     Drinks%  Home%  Beauty%  Health%  Baby%  Pets%
# 25     3.46  15.93      0.0      0.0    0.0    0.0
# 44    10.26   0.00      0.0      0.0    0.0    0.0
# 55    33.55  12.69      0.0      0.0    0.0    0.0
# 58    15.74  17.75      0.0      0.0    0.0    0.0
# 59    18.03   8.45      7.2      0.0    0.0    0.0

# %%
# Sorting
df.sort_values("total_items", ascending=False).head()
# Out:
#        customer  order  total_items  discount%  weekday  hour  Food%  Fresh%  \
# 16831      5656  16831          298       3.83        3    18  49.27    0.00
# 29977     10226  29977          282       0.70        2    15  45.10    0.00
# 24893      8228  24893          236       2.32        3    19  34.41   48.30
# 10634      3632  10634          226      10.97        2    11  23.36   29.42
# 16684      5609  16684          222       5.16        7    11  26.73    0.95
#
#        Drinks%  Home%  Beauty%  Health%  Baby%  Pets%
# 16831    32.36  16.70     0.00      0.0    0.0    0.0
# 29977    26.68  28.22     0.00      0.0    0.0    0.0
# 24893    10.50   4.45     2.34      0.0    0.0    0.0
# 10634     0.83  21.32    25.07      0.0    0.0    0.0
# 16684    35.19  18.89    18.24      0.0    0.0    0.0

# %%
# Add product category percentages as a check
df['Total%'] = df['Food%'] + df['Fresh%'] + df['Drinks%'] + df['Home%'] + df['Beauty%'] + df['Health%'] + df['Baby%'] + df['Pets%']
df.describe()
# Out:
#            customer         order   total_items     discount%       weekday  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    5012.483367  14999.500000     31.739933      8.455495      3.642367
# std     2888.646245   8660.398374     20.576579     14.199350      2.122031
# min        0.000000      0.000000      1.000000    -65.150000      1.000000
# 25%     2541.750000   7499.750000     18.000000      1.177500      2.000000
# 50%     5043.000000  14999.500000     29.000000      4.160000      3.000000
# 75%     7483.000000  22499.250000     41.000000      9.990000      5.000000
# max    10238.000000  29999.000000    298.000000    100.000000      7.000000
#
#                hour         Food%        Fresh%       Drinks%         Home%  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      15.034667     23.560406     20.227279     23.349235     13.539575
# ...
